# %%
# !pip install psycopg2
# !pip install matplotlib
# !pip install pandas
# !pip install tqdm
# !pip install folium
# !pip install juliacall
from juliacall import Main as jl
jl.Pkg.add("OnlineStats")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting psycopg2
#   Using cached psycopg2-2.9.9.tar.gz (384 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: psycopg2
#   Building wheel for psycopg2 (setup.py) ... done
#   Created wheel for psycopg2: filename=psycopg2-2.9.9-cp310-cp310-linux_x86_64.whl size=499010 sha256=550e742a825d91e61d2b0666dfedaa4a1682e383e6eb49752c53af0320ec96ae
#   Stored in directory: /home/admin/.cache/pip/wheels/7d/75/13/da1c6d88687ae81bf5e3cfa07d702981ba137963163472b050
# Successfully built psycopg2
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.9
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/admin/.local/lib/python3.10/site-packages (3.8.0)
# Requirement already satisfied: numpy<2,>=1.21 in /home/admin/.local/lib/python3.10/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/admin/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/admin/.local/lib/python3.10/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/admin/.local/lib/python3.10/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/admin/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/admin/.local/lib/python3.10/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/admin/.local/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/admin/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/admin/.local/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.22.4 in /home/admin/.local/lib/python3.10/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /home/admin/.local/lib/python3.10/site-packages (4.66.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in /home/admin/.local/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /home/admin/.local/lib/python3.10/site-packages (from folium) (0.6.0)
# Requirement already satisfied: numpy in /home/admin/.local/lib/python3.10/site-packages (from folium) (1.26.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->folium) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: juliacall in /home/admin/.local/lib/python3.10/site-packages (0.9.14)
# Requirement already satisfied: juliapkg~=0.1.8 in /home/admin/.local/lib/python3.10/site-packages (from juliacall) (0.1.10)
# Requirement already satisfied: semantic-version~=2.9 in /home/admin/.local/lib/python3.10/site-packages (from juliapkg~=0.1.8->juliacall) (2.10.0)
# [juliapkg] Locating Julia ^1.6.1
# [juliapkg] Using Julia 1.9.3 at /home/admin/julia/julia-1.9.3/bin/julia
# [juliapkg] Using Julia project at /home/admin/.julia/environments/pyjuliapkg
# [juliapkg] Installing packages:
#            julia> import Pkg
#            julia> Pkg.add([Pkg.PackageSpec(name="PythonCall", uuid="6099a3de-0909-46bc-b1f4-468b9a2dfc0d")])
#            julia> Pkg.resolve()
#            julia> Pkg.precompile()
#   Installing known registries into `~/.julia`
# ┌ Warning: could not download https://pkg.julialang.org/registries
# │   exception = RequestError: HTTP/2 502 while requesting https://pkg.julialang.org/registries
# └ @ Pkg.Registry ~/julia/julia-1.9.3/share/julia/stdlib/v1.9/Pkg/src/Registry/Registry.jl:69
# ┌ Warning: could not download https://pkg.julialang.org/registries
# │   exception = RequestError: HTTP/2 301 (Operation too slow. Less than 1 bytes/sec transferred the last 20 seconds) while requesting https://pkg.julialang.org/registries
# └ @ Pkg.Registry ~/julia/julia-1.9.3/share/julia/stdlib/v1.9/Pkg/src/Registry/Registry.jl:69
#      Cloning registry from "https://github.com/JuliaRegistries/General.git"
#        Added registry `General` to `~/.julia/registries/General`
# ┌ Warning: could not download https://pkg.julialang.org/registries
# │   exception = RequestError: HTTP/2 502 while requesting https://pkg.julialang.org/registries
# └ @ Pkg.Registry ~/julia/julia-1.9.3/share/julia/stdlib/v1.9/Pkg/src/Registry/Registry.jl:69
#     Updating registry at `~/.julia/registries/General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
# ┌ Warning: could not download https://pkg.julialang.org/registries
# │   exception = RequestError: HTTP/2 502 while requesting https://pkg.julialang.org/registries
# └ @ Pkg.Registry ~/julia/julia-1.9.3/share/julia/stdlib/v1.9/Pkg/src/Registry/Registry.jl:69
#    Installed Parsers ───────────────────── v2.7.2
#    Installed MicroMamba ────────────────── v0.1.14
#    Installed TableTraits ───────────────── v1.0.1
#    Installed Tables ────────────────────── v1.11.0
#    Installed JSON3 ─────────────────────── v1.13.2
#    Installed Scratch ───────────────────── v1.2.0
#    Installed Preferences ───────────────── v1.4.1
#    Installed PythonCall ────────────────── v0.9.14
#    Installed IteratorInterfaceExtensions ─ v1.0.0
#    Installed DataAPI ───────────────────── v1.15.0
#    Installed JLLWrappers ───────────────── v1.5.0
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed PrecompileTools ───────────── v1.2.0
#    Installed Pidfile ───────────────────── v1.3.0
#    Installed Requires ──────────────────── v1.3.0
#    Installed micromamba_jll ────────────── v1.4.9+0
#    Installed OrderedCollections ────────── v1.6.2
#    Installed StructTypes ───────────────── v1.10.0
#    Installed MacroTools ────────────────── v0.5.11
#    Installed UnsafePointers ────────────── v1.0.0
#    Installed CondaPkg ──────────────────── v0.2.21
#     Updating `~/.julia/environments/pyjuliapkg/Project.toml`
#   [6099a3de] + PythonCall v0.9.14
#     Updating `~/.julia/environments/pyjuliapkg/Manifest.toml`
#   [992eb4ea] + CondaPkg v0.2.21
#   [9a962f9c] + DataAPI v1.15.0
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [692b3bcd] + JLLWrappers v1.5.0
#   [0f8b85d8] + JSON3 v1.13.2
#   [1914dd2f] + MacroTools v0.5.11
#   [0b3b1443] + MicroMamba v0.1.14
#   [bac558e1] + OrderedCollections v1.6.2
#   [69de0a69] + Parsers v2.7.2
#   [fa939f87] + Pidfile v1.3.0
#   [aea7be01] + PrecompileTools v1.2.0
#   [21216c6a] + Preferences v1.4.1
#   [6099a3de] + PythonCall v0.9.14
#   [ae029012] + Requires v1.3.0
#   [6c6a2e73] + Scratch v1.2.0
#   [856f2bd8] + StructTypes v1.10.0
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.11.0
#   [e17b2a0c] + UnsafePointers v1.0.0
#   [f8abcde7] + micromamba_jll v1.4.9+0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b77e0a4c] + InteractiveUtils
#   [4af54fe1] + LazyArtifacts
#   [b27032c2] + LibCURL v0.6.3
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [44cfe95a] + Pkg v1.9.2
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [6462fe0b] + Sockets
#   [fa267f1f] + TOML v1.0.3
#   [a4e569a6] + Tar v1.10.0
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.5+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.2+0
#   [14a3606d] + MozillaCACerts_jll v2022.10.11
#   [4536629a] + OpenBLAS_jll v0.3.21+4
#   [83775a58] + Zlib_jll v1.2.13+0
#   [8e850b90] + libblastrampoline_jll v5.8.0+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#   [3f19e933] + p7zip_jll v17.4.0+0
# Precompiling project...
#   ✓ DataValueInterfaces
#   ✓ UnsafePointers
#   ✓ IteratorInterfaceExtensions
#   ✓ CompilerSupportLibraries_jll
#   ✓ DataAPI
#   ✓ Requires
#   ✓ OrderedCollections
#   ✓ Pidfile
#   ✓ Scratch
#   ✓ StructTypes
#   ✓ Preferences
#   ✓ TableTraits
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ✓ Tables
#   ✓ MacroTools
#   ✓ micromamba_jll
#   ✓ MicroMamba
#   ✓ Parsers
#   ✓ JSON3
#   ✓ CondaPkg
#   ✓ PythonCall
#   22 dependencies successfully precompiled in 56 seconds. 3 already precompiled.
#   1 dependency had warnings during precompilation:
# ┌ micromamba_jll [f8abcde7-e9b7-5caa-b8af-a437887ae8e4]
# │  Downloading artifact: micromamba
# └
#   No Changes to `~/.julia/environments/pyjuliapkg/Project.toml`
#   No Changes to `~/.julia/environments/pyjuliapkg/Manifest.toml`
# ┌ Warning: could not download https://pkg.julialang.org/registries
# │   exception = RequestError: HTTP/2 502 while requesting https://pkg.julialang.org/registries
# └ @ Pkg.Registry ~/julia/julia-1.9.3/share/julia/stdlib/v1.9/Pkg/src/Registry/Registry.jl:69
#    Resolving package versions...
# ┌ Warning: could not download https://pkg.julialang.org/registries
# │   exception = RequestError: HTTP/2 301 (Operation too slow. Less than 1 bytes/sec transferred the last 20 seconds) while requesting https://pkg.julialang.org/registries
# └ @ Pkg.Registry ~/julia/julia-1.9.3/share/julia/stdlib/v1.9/Pkg/src/Registry/Registry.jl:69
#    Installed IrrationalConstants ───── v0.2.2
#    Installed Calculus ──────────────── v0.5.1
#    Installed Rmath ─────────────────── v0.7.1
#    Installed DualNumbers ───────────── v0.6.8
#    Installed HypergeometricFunctions ─ v0.3.23
#    Installed OnlineStatsBase ───────── v1.6.1
#    Installed StatsFuns ─────────────── v1.3.0
#    Installed SpecialFunctions ──────── v2.3.1
#    Installed NaNMath ───────────────── v1.0.2
#    Installed FillArrays ────────────── v1.6.1
#    Installed RecipesBase ───────────── v1.3.4
#    Installed Reexport ──────────────── v1.2.2
#    Installed PDMats ────────────────── v0.11.25
#    Installed AbstractTrees ─────────── v0.4.4
#    Installed QuadGK ────────────────── v2.9.1
#    Installed LogExpFunctions ───────── v0.3.26
#    Installed Compat ────────────────── v4.10.0
#    Installed Rmath_jll ─────────────── v0.4.0+0
#    Installed StatsAPI ──────────────── v1.7.0
#    Installed DataStructures ────────── v0.18.15
#    Installed OpenSpecFun_jll ───────── v0.5.5+0
#    Installed SortingAlgorithms ─────── v1.1.1
#    Installed Distributions ────────��── v0.25.102
#    Installed Missings ──────────────── v1.1.0
#    Installed StatsBase ─────────────── v0.34.2
#    Installed DocStringExtensions ───── v0.9.3
#    Installed OnlineStats ───────────── v1.6.3
#     Updating `~/.julia/environments/pyjuliapkg/Project.toml`
#   [a15396b6] + OnlineStats v1.6.3
#     Updating `~/.julia/environments/pyjuliapkg/Manifest.toml`
#   [1520ce14] + AbstractTrees v0.4.4
#   [49dc2e85] + Calculus v0.5.1
#   [34da2185] + Compat v4.10.0
#   [864edb3b] + DataStructures v0.18.15
#   [31c24e10] + Distributions v0.25.102
#   [ffbed154] + DocStringExtensions v0.9.3
#   [fa6b7ba4] + DualNumbers v0.6.8
#   [1a297f60] + FillArrays v1.6.1
#   [34004b35] + HypergeometricFunctions v0.3.23
#   [92d709cd] + IrrationalConstants v0.2.2
#   [2ab3a3ac] + LogExpFunctions v0.3.26
#   [e1d29d7a] + Missings v1.1.0
#   [77ba4419] + NaNMath v1.0.2
#   [a15396b6] + OnlineStats v1.6.3
#   [925886fa] + OnlineStatsBase v1.6.1
#   [90014a1f] + PDMats v0.11.25
#   [1fd47b50] + QuadGK v2.9.1
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [189a3867] + Reexport v1.2.2
#   [79098fc4] + Rmath v0.7.1
#   [a2af1166] + SortingAlgorithms v1.1.1
#   [276daf66] + SpecialFunctions v2.3.1
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.2
#   [4c63d2b9] + StatsFuns v1.3.0
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [f50d1b31] + Rmath_jll v0.4.0+0
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics v1.9.0
#   [4607b0f0] + SuiteSparse
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [bea87d4a] + SuiteSparse_jll v5.10.1+6
# Precompiling project...
#   ✓ Reexport
#   ✓ Compat
#   ✓ DocStringExtensions
#   ✓ FillArrays
#   ✓ Calculus
#   ✓ AbstractTrees
#   ✓ StatsAPI
#   ✓ NaNMath
#   ✓ IrrationalConstants
#   ✓ Missings
#   ✓ PDMats
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ OpenSpecFun_jll
#   ✓ Rmath_jll
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ LogExpFunctions
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ Rmath
#   ✓ RecipesBase
#   ✓ DataStructures
#   ✓ SortingAlgorithms
#   ✓ QuadGK
#   ✓ SpecialFunctions
#   ✓ DualNumbers
#   ✓ StatsBase
#   ✓ OnlineStatsBase
#   ✓ HypergeometricFunctions
#   ✓ StatsFuns
#   ✓ Distributions
#   ✓ OnlineStats
#   30 dependencies successfully precompiled in 18 seconds. 29 already precompiled.
