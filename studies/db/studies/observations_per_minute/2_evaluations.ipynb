# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import json

with open('outputs/primary_signal_observations_per_minute_timestamp_counts.json', 'r') as fp:
    primary_signal_observations_per_minute_timestamp_counts = json.load(fp)

dates = []
counts = []

for timestamp, count in primary_signal_observations_per_minute_timestamp_counts.items():
    timestamp = float(timestamp)
    if timestamp < 1694607780:
        continue
    dates.append(datetime.datetime.fromtimestamp(timestamp))
    counts.append(count)

fig, ax = plt.subplots(figsize=(20,10))
ax.plot(dates, counts, label="Total")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%d %H:%M'))
ax.set_xlabel('Timestamp')
ax.set_ylabel('Count')
ax.set_title('Count of total primary signal observations per minute')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import json

with open('outputs/primary_signal_observations_per_minute_timestamp_counts_bike.json', 'r') as fp:
    primary_signal_observations_per_minute_timestamp_counts_bike = json.load(fp)


with open('outputs/primary_signal_observations_per_minute_timestamp_counts_bike_mqtt.json', 'r') as fp:
    primary_signal_observations_per_minute_timestamp_counts_bike_mqtt = json.load(fp)

dates = []
counts = []

for timestamp, count in primary_signal_observations_per_minute_timestamp_counts_bike.items():
    timestamp = float(timestamp)
    if timestamp < 1694607780:
        continue
    dates.append(datetime.datetime.fromtimestamp(timestamp))
    counts.append(count)
    
dates_mqtt = []
counts_mqtt = []

for timestamp, count in primary_signal_observations_per_minute_timestamp_counts_bike_mqtt.items():
    timestamp = float(timestamp)
    if timestamp < 1694607780:
        continue
    dates_mqtt.append(datetime.datetime.fromtimestamp(timestamp))
    counts_mqtt.append(count)

fig, ax = plt.subplots(figsize=(20,10))
ax.plot(dates, counts, label="Total")
ax.plot(dates_mqtt, counts_mqtt, label="MQTT")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%d %H:%M'))
ax.set_xlabel('Timestamp')
ax.set_ylabel('Count')
ax.set_title('Count of total bike primary signal observations per minute')
ax.legend()
plt.show()
